# %%
# !hdfs dfs -ls /labs/slaba04/
# Out:
# Found 1 items
# -rw-r--r--   3 hdfs hdfs  655090069 2021-02-27 22:13 /labs/slaba04/gender_age_dataset.txt

# %%
import os
import sys
os.environ["PYSPARK_PYTHON"]='/opt/anaconda/envs/bd9/bin/python'
os.environ["SPARK_HOME"]='/usr/hdp/current/spark2-client'
os.environ["PYSPARK_SUBMIT_ARGS"]='--num-executors 3 pyspark-shell'

spark_home = os.environ.get('SPARK_HOME', None)

sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.10.7-src.zip'))

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
conf = SparkConf()
conf.set("spark.app.name", "ZK Lab04 app") 

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %%
schema_test = StructType(fields=[StructField('gender', StringType()), 
                                       StructField('age', StringType()),
                                       StructField('uid', StringType()),
                                       StructField('user_json', StringType())
                                      ])
tdf = spark.read\
.format('csv')\
.schema(schema_test)\
.option("header", "true")\
.option("delimiter", "\t")\
.load("/labs/slaba04/gender_age_dataset.txt")

tdf
# Out:
# DataFrame[gender: string, age: string, uid: string, user_json: string]

# %%
from pyspark.sql.functions import *

visits_schema = StructType([
    StructField("visits", ArrayType(
      StructType([
          StructField("url", StringType()),
          StructField("timestamp", LongType())
      ])
   ))
])

tdf2 = tdf.withColumn("visits", from_json("user_json", visits_schema))

tdf2.show(2)
# Out:
# +------+-----+--------------------+--------------------+--------------------+
# |gender|  age|                 uid|           user_json|              visits|
# +------+-----+--------------------+--------------------+--------------------+
# |     F|18-24|d50192e5-c44e-4ae...|{"visits": [{"url...|[[[http://zebra-z...|
# |     M|25-34|d502331d-621e-472...|{"visits": [{"url...|[[[http://sweetra...|
# +------+-----+--------------------+--------------------+--------------------+
# only showing top 2 rows

# %%
tdf2.rdd.getNumPartitions()
# Out:
# 5

# %%
tdf2 = tdf2.repartition(6)
tdf2.rdd.getNumPartitions()
# Out:
# 6

# %%
from pyspark.sql import functions as F
train_data = tdf2.withColumn('visited_pages', F.col('visits.visits.url'))
train_data.show(1, False, True)
# Out:
# -RECORD 0---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  gender        | M
#  age           | 25-34
#  uid           | 1f6d6ba1-4211-4368-8b1d-18728e725f1f
#  user_json     | {"visits": [{"url": "http://www.job.ru/seeker/job/", "timestamp": 1427263717000}, {"url": "http://www.job.ru/seeker/job/", "timestamp": 1427263716000}, {"url": "https://www.avito.ru/sankt-peterburg/vakansii/trebuyutsya_svarschiki_mkonstruktsiy_ruchn._poluavt._252703008", "timestamp": 1427210718000}, {"url": "https://www.avito.ru/sankt-peterburg/vakansii/trebuyutsya_svarschiki_mkonstruktsiy_ruchn._poluavt._252703008", "timestamp": 1427209899000}, {"url": "https://www.avito.ru/sankt-peterburg/vakansii/svarschik_kuzovschik_srochno_533100466", "timestamp": 1427209140000}, {"url": "http://sankt-peterburg.trud.com/companies/obuhovskij-zavod/", "timestamp": 1427208762000}, {"url": "https://www.avito.ru/sankt-peterburg/vakansii/treuetsya_svarschik_528683687", "timestamp": 1427208412000}, {"url": "http://gidonlinekino.com/2012/03/gorod-v-ogne/", "timestamp": 1427128317000}, {"url": "http://gidonlinekino.com/2015/02/vyzov-bezdne-3d/", "timestamp": 1426913805000}, {"url": "http://www.gismeteo.ru/month/4079/", "timestamp": 1426731254000}, {"url": "http://www.gismeteo.ru/city/hourly/4079/2/", "timestamp": 1426731165000}, {"url": "http://gidonlinekino.com/2015/01/priklyucheniya-paddingtona/", "timestamp": 1426706565000}, {"url": "http://forums.playground.ru/movies/", "timestamp": 1426692792001}, {"url": "http://go.mail.ru/search?q=\u043a\u0440\u044b\u043c. \u043f\u0443\u0442\u044c \u043d\u0430 \u0440\u043e\u0434\u0438\u043d\u0443. \u0444\u0438\u043b\u044c\u043c \u0430\u043d\u0434\u0440\u0435\u044f \u043a\u043e\u043d\u0434\u0440\u0430\u0448\u043e\u0432\u0430 (2015) \u0441\u043c\u043e\u0442\u0440\u0435\u0442\u044c&us=56&usln=1&usstr=\u043a\u0440\u044b\u043c. \u043f\u0443\u0442\u044c \u043d\u0430 \u0440\u043e\u0434\u0438\u043d\u0443. \u0444\u0438\u043b\u044c\u043c \u0430\u043d\u0434\u0440\u0435\u044f \u043a\u043e\u043d\u0434\u0440\u0430\u0448\u043e\u0432\u0430 (2015) \u0441\u043c\u043e&hasnavig=0", "timestamp": 1426692792000}]}
#  visits        | [[[http://www.job.ru/seeker/job/, 1427263717000], [http://www.job.ru/seeker/job/, 1427263716000], [https://www.avito.ru/sankt-peterburg/vakansii/trebuyutsya_svarschiki_mkonstruktsiy_ruchn._poluavt._252703008, 1427210718000], [https://www.avito.ru/sankt-peterburg/vakansii/trebuyutsya_svarschiki_mkonstruktsiy_ruchn._poluavt._252703008, 1427209899000], [https://www.avito.ru/sankt-peterburg/vakansii/svarschik_kuzovschik_srochno_533100466, 1427209140000], [http://sankt-peterburg.trud.com/companies/obuhovskij-zavod/, 1427208762000], [https://www.avito.ru/sankt-peterburg/vakansii/treuetsya_svarschik_528683687, 1427208412000], [http://gidonlinekino.com/2012/03/gorod-v-ogne/, 1427128317000], [http://gidonlinekino.com/2015/02/vyzov-bezdne-3d/, 1426913805000], [http://www.gismeteo.ru/month/4079/, 1426731254000], [http://www.gismeteo.ru/city/hourly/4079/2/, 1426731165000], [http://gidonlinekino.com/2015/01/priklyucheniya-paddingtona/, 1426706565000], [http://forums.playground.ru/movies/, 1426692792001], [http://go.mail.ru/search?q=крым. путь на родину. фильм андрея кондрашова (2015) смотреть&us=56&usln=1&usstr=крым. путь на родину. фильм андрея кондрашова (2015) смо&hasnavig=0, 1426692792000]]]
#  visited_pages | [http://www.job.ru/seeker/job/, http://www.job.ru/seeker/job/, https://www.avito.ru/sankt-peterburg/vakansii/trebuyutsya_svarschiki_mkonstruktsiy_ruchn._poluavt._252703008, https://www.avito.ru/sankt-peterburg/vakansii/trebuyutsya_svarschiki_mkonstruktsiy_ruchn._poluavt._252703008, https://www.avito.ru/sankt-peterburg/vakansii/svarschik_kuzovschik_srochno_533100466, http://sankt-peterburg.trud.com/companies/obuhovskij-zavod/, https://www.avito.ru/sankt-peterburg/vakansii/treuetsya_svarschik_528683687, http://gidonlinekino.com/2012/03/gorod-v-ogne/, http://gidonlinekino.com/2015/02/vyzov-bezdne-3d/, http://www.gismeteo.ru/month/4079/, http://www.gismeteo.ru/city/hourly/4079/2/, http://gidonlinekino.com/2015/01/priklyucheniya-paddingtona/, http://forums.playground.ru/movies/, http://go.mail.ru/search?q=крым. путь на родину. фильм андрея кондрашова (2015) смотреть&us=56&usln=1&usstr=крым. путь на родину. фильм андрея кондрашова (2015) смо&hasnavig=0]
# only showing top 1 row

# %%
from pyspark.sql.functions import concat, col, lit
train_df = train_data.withColumn('concat', concat("gender", lit(":"), "age"))\
.filter((F.col('gender') != '-') | (F.col('age') != '-'))\
.select('uid','visited_pages','concat')
# train_df.count()
train_df.show(1, False, True)
# Out:
# -RECORD 0---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  uid           | abea25c4-850b-4857-9b4b-475362c9b403
#  visited_pages | [http://www.turizm.ru/ski/articles/gornye_lyzhi_kak_ne_oshibitsya_pri_pokupke_snaryazheniya/, http://www.sports.ru/tribuna/blogs/televizor3/756396.html, http://p1spb.ru/news/vo_frunzenskom_rajone_peterburga_legkovoj_avtomobil_ford_stolknulsja_s_ehlektrovozom/2015-03-23-8681, http://p1spb.ru/news/vo_frunzenskom_rajone_peterburga_legkovoj_avtomobil_ford_stolknulsja_s_ehlektrovozom/2015-03-23-8681, http://rrnews.ru/news/u4846/2015/03/23/112411, http://loveplanet.ru/a-look/time-5/item-1/, http://ctv.by/novosti-belgii/sobaka-ispolnila-pesnyu-uitni-hyuston-na-shou-v-belgii-i-proizvela-furor?, http://www.ctv.by/novosti-belgii/sobaka-ispolnila-pesnyu-uitni-hyuston-na-shou-v-belgii-i-proizvela-furor, http://mirfactov.com/sobaka-ispolnila-pesnyu-uitni-hyuston-na-shou-v-belgii/, http://mirfactov.com/sobaka-ispolnila-pesnyu-uitni-hyuston-na-shou-v-belgii/, http://russian.rt.com/article/80958, http://russian.rt.com/article/80900, http://russian.rt.com/article/80900, http://pages.ebay.de/services/forum/feedback.html, http://www.eurosport.ru/ski-jumping/vikersund/2014-2015/story_sto4604223.shtml, http://www.regnum.ru/news/polit/1906768.html, http://vk.com/feed, http://www.aif.ru/society/nature/1470968, http://www.aif.ru/society/nature/1470968, http://news.yandex.ru/yandsearch?cl4url=www.aif.ru/society/nature/1470968&lang=ru&lr=2, http://loveplanet.ru/, http://loveplanet.ru/a-search/item-1/d-1/foto-1/pol-1/spol-2/bage-22/tage-27/geo-3159,4925,4962/online-1/country-3159/region-4925/city-4962/, http://loveplanet.ru/a-search/item-1/d-1/foto-1/pol-1/spol-2/bage-22/tage-27/geo-3159,4925,4962/online-1/country-3159/region-4925/city-4962/, http://loveplanet.ru/, http://www.ebay.de/, http://www.ebay.de/sch/7294/i.html/druckfeder sram, http://www.ebay.de/sch/i.html, http://www.ebay.de/, http://www.ebay.de/sch/i.html, http://www.ebay.de/sch/i.html, http://www.ebay.de/, http://www.ebay.de/sch/i.html, http://www.ebay.de/, http://www.ebay.de/sch/7294/i.html, http://www.ebay.de/sch/i.html, http://www.ebay.de/, http://www.ebay.de/sch/7294/i.html/spring sram derailleur, http://www.ebay.de/sch/7294/i.html/spring sram derailleur, http://www.ebay.de/sch/i.html, http://www.kp.ru/online/news/2005704/, http://www.ebay.com/, http://edp1.adriver.ru/images/0003754/0003754952/0/index.html?html_params=bid=3754952&sid=45736&width=0&height=0&rnd=9474851&pz=0&ad=466699&bt=52&bn=206&ar_sliceid=1496208&ntype=0&nid=0&url=//ad.adriver.ru/cgi-bin/click.cgi%3fsid%3d45736%26ad%3d466699%26bid%3d3754952%26bt%3d52%26bn%3d206%26pz%3d0%26xpid%3dc5lxtpz6lccotvmyk2gitoakv9gtvxlww%26ref%3dhttp%3a%252f%252fria.ru%252feconomy%252f20150318%252f1053311923.html%26custom%3d%26rleurl%3d&comppath=http%3a//edp1.adriver.ru/images/0003754/0003754952/0/, https://reg.ebay.de/reg/partialreg, https://reg.ebay.de/reg/partialreg]
#  concat        | M:25-34
# only showing top 1 row

# %%
train_df2 = train_df.withColumn("new_column",expr('transform(visited_pages,x -> split(x,"://")[1])'))
train_df3 = train_df2.withColumn("hosts",expr('transform(new_column,x -> split(x,"/")[0])'))\
.select('uid','visited_pages','hosts','concat')
train_df4 = train_df3.withColumn("count", F.size("hosts")) \
            .withColumn("count_distinct", F.size(F.array_distinct("hosts")))

train_df4.show(1, False, True)
# Out:
# -RECORD 0----------------------------------------------
#  uid            | 0d52ad4d-27dc-4211-95fe-0174abe1c5f5
#  visited_pages  | [http://www.dez-shchukino.ru/]
#  hosts          | [www.dez-shchukino.ru]
#  concat         | M:35-44
#  count          | 1
#  count_distinct | 1
# only showing top 1 row

# %%
train_df5 = train_df4.withColumn('fr_h', F.col('count')/F.col('count_distinct'))
train_df5.show(2,False,True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  uid            | 5fa9da5a-0d75-4a29-aaa1-7475732f12ee
#  visited_pages  | [http://govoritmoskva.ru/interviews/499/, http://news.smi2.ru/newdata/news?ad=706303&bl=80357&st=16&ct=adpreview&out=1, http://www.womanhit.ru/stars/gossips/, http://www.womanhit.ru/stars/gossips/]
#  hosts          | [govoritmoskva.ru, news.smi2.ru, www.womanhit.ru, www.womanhit.ru]
#  concat         | M:25-34
#  count          | 4
#  count_distinct | 3
#  fr_h           | 1.3333333333333333
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  uid            | f7d96711-0069-4897-bcf8-8eba68f4c3d4
#  visited_pages  | [http://gotovim-doma.ru/view.php?tag=video-recepty, http://gotovim-doma.ru/view.php?r=128-recept-salat-iz-kapusty-s-krabovymi-palochkami, http://gotovim-doma.ru/view.php?r=98-recept-salat-iz-krabovykh-palochek-s-kukuruzoi, http://enc-dic.com/fwords/margerity-21288.html, http://enc-dic.com/synonym/margerit-131029.html, http://fishki.net/1471148-pravila-muzhchiny-u-kotorogo-est-doch.html?from=fb]
#  hosts          | [gotovim-doma.ru, gotovim-doma.ru, gotovim-doma.ru, enc-dic.com, enc-dic.com, fishki.net]
#  concat         | F:25-34
#  count          | 6
#  count_distinct | 3
#  fr_h           | 2.0
# only showing top 2 rows

# %% [markdown]
# RandomForestClassifier

# %%
dataset_forRF = train_df5.select('concat','hosts')
dataset_forRF.show(2)
# Out:
# +-------+--------------------+
# | concat|               hosts|
# +-------+--------------------+
# |F:25-34|[love.mail.ru, go...|
# | M:>=55|   [worldoftanks.ru]|
# +-------+--------------------+
# only showing top 2 rows

# %%
indexer = StringIndexer(inputCol="concat", outputCol="label")

pipeline_pre = Pipeline(stages=[
    CountVectorizer(inputCol="hosts", outputCol="features"),
    indexer
    ])

dataset_rfFit = pipeline_pre.fit(dataset_forRF)
dataset_rf = dataset_rfFit.transform(dataset_forRF)
dataset_rf.show(1)
# Out:
# +-------+--------------------+--------------------+-----+
# | concat|               hosts|            features|label|
# +-------+--------------------+--------------------+-----+
# |M:35-44|[www.dez-shchukin...|(115071,[96919],[...|  2.0|
# +-------+--------------------+--------------------+-----+
# only showing top 1 row

# %%
fractions = dataset_rf.select("label").distinct().withColumn("fraction", lit(0.8)).rdd.collectAsMap()
print(fractions)                                                            

sampled_df_rf = dataset_rf.stat.sampleBy("label", fractions, seed = 36138)  
sampled_df_rf.show(5)
# Out:
# {8.0: 0.8, 0.0: 0.8, 7.0: 0.8, 1.0: 0.8, 4.0: 0.8, 3.0: 0.8, 2.0: 0.8, 6.0: 0.8, 5.0: 0.8, 9.0: 0.8}
# +-------+--------------------+--------------------+-----+
# | concat|               hosts|            features|label|
# +-------+--------------------+--------------------+-----+
# | M:>=55|   [worldoftanks.ru]|(115071,[204],[1.0])|  9.0|
# | F:>=55|[plirt.ru, plirt....|(115071,[11,36,38...|  8.0|
# |F:25-34|[www.1001eda.com,...|(115071,[341,570,...|  1.0|
# |M:35-44|[bigcinema.tv, bi...|(115071,[42,68404...|  2.0|
# |M:35-44|[loveplanet.ru, l...|(115071,[5,40],[2...|  2.0|
# +-------+--------------------+--------------------+-----+
# only showing top 5 rows

# %%
testData_rf = dataset_rf.exceptAll(sampled_df_rf)
testData_rf.count()
# Out:
# 7228

# %%
rf = RandomForestClassifier(
        labelCol="label", featuresCol="features", numTrees=20, 
        maxBins=32, maxDepth=15, seed=9001,
    )
rfModel = rf.fit(sampled_df_rf)

predictions_rf = rfModel.transform(testData_rf)

# %%
predictions_rf.show(5,False,True)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#  concat        | F:25-34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
#  hosts         | [kosmetista.ru, www.svyaznoy.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, www.ozon.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, vet-centr.ucoz.ru, www.svyaznoy.ru, cache.betweendigital.com, vet-centr.ucoz.ru, www.svyaznoy.ru, vet-centr.ucoz.ru, www.svyaznoy.ru, vet-centr.ucoz.ru, www.svyaznoy.ru, irecommend.ru, kosmetista.ru, kosmetista.ru, kosmetista.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, podolsk-life.ru, vet-centr.ucoz.ru]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
#  features      | (115071,[13,14,72,82,161,7242,37141],[27.0,5.0,75.0,1.0,1.0,30.0,5.0])                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
#  label         | 1.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#  rawPrediction | [4.6653383273405735,4.125325570587528,2.6410757586161306,2.462082130329068,1.6634919962152483,1.45060946833593,1.0623247258588833,1.0642100868898816,0.4942372413314716,0.3713046944952851]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
#  probability   | [0.23326691636702865,0.20626627852937635,0.13205378793080652,0.12310410651645338,0.0831745998107624,0.07253047341679648,0.05311623629294415,0.05321050434449407,0.024711862066573578,0.018565234724764252]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#  prediction    | 0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# -RECORD 1------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#  concat        | F:35-44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
#  hosts         | [ru.wowhead.com, ru.wowhead.com, ru.wowhead.com, ru.wowhead.com, ru.wowhead.com, ru.wowhead.com, ru.wowhead.com, www.avito.ru, www.avito.ru, www.avito.ru, www.avito.ru, www.avito.ru, www.avito.ru, b-track.ru, http, korastudio.ru, korastudio.ru, korastudio.ru, korastudio.ru, korastudio.ru, mphotography.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, kazan.fashion-box.ru, go.mail.ru, kazan.fashion-box.ru, pass.rzd.ru, pass.rzd.ru, rzd.ru, rzd.ru, www.tks.ru, games.mail.ru, http, http, www.hotel-central.ru, www.hotel-central.ru, games.mail.ru, pass.rzd.ru, pass.rzd.ru, pass.rzd.ru, pass.rzd.ru, rzd.ru, www.tks.ru, masterh4.adriver.ru, masterh4.adriver.ru, http, http, http, kznmed.ru, kznmed.ru, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, http, www.sapato.ru, games.mail.ru, www.tks.ru, http, supersoftware.ru, softreview.ucoz.ru, www.tks.ru, http, http, http, games.mail.ru, games.mail.ru, http, www.playground.ru, http, http, urist-proffi.ru, google.ru, www.tks.ru, ftp.prav.tatar.ru, games.mail.ru, www.tks.ru, http, www.xstory.ru, xstory.ru, yandex.ru, www.perevod-pesen.ru, www.perevod-pesen.ru, iplayer.fm, http, http, http, http, http, games.mail.ru, games.mail.ru, games.mail.ru, http, tks.ru, vk.com, www.tks.ru, http, http, prazdnik-na-bis.com, http, http, www.tks.ru, www.youtube.com, www.youtube.com, www.youtube.com, www.news.com.au, www.news.com.au, www.news.com.au, ams1.ib.adnxs.com, www.news.com.au, www.news.com.au, www.news.com.au, www.news.com.au, www.heraldsun.com.au, www.heraldsun.com.au, www.playground.ru, forums.playground.ru, forums.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, uslugi-moscow.ru, www.tks.ru, www.maxikarta.ru, uslugi-moscow.ru, www.esosedi.ru, www.playground.ru, www.playground.ru, www.efremova.info, www.efremova.info, www.efremova.info, www.efremova.info, vsegost.com, vsegost.com, www.mtomd.info, vsegost.com, www.mtomd.info, artvid.ru, www.playground.ru, www.tks.ru, www.playground.ru, www.playground.ru, pregnancy.ucoz.com, www.vstrahovanie.ru, kazan.spravochnikov.ru, games.mail.ru, games.mail.ru, games.mail.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, ctc-metar.ru, finansiko.ru, finansiko.ru, www.playground.ru, www.playground.ru, www.playground.ru, games.mail.ru, games.mail.ru, www.tks.ru, womanadvice.ru, www.domsovetof.ru, ladymadonna.ru, ladymadonna.ru, art16.ru, kazan24.ru, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, www.playground.ru, ru.wow.wikia.com, www.translate.ru, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, ru.wow.wikia.com, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, yubiley.org, www.tks.ru, www.playground.ru, forums.playground.ru, forums.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, www.playground.ru, kazan.ros-spravka.ru, www.playground.ru, www.1za ...
# ...
#  rawPrediction | [4.776442148852562,3.5841659950179223,3.101394558395107,2.284616389140521,1.4727721655307955,1.3780216093096556,1.2947213410882175,1.0796867059883157,0.5148103586386314,0.5133687280382738]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#  probability   | [0.23882210744262808,0.1792082997508961,0.15506972791975535,0.11423081945702604,0.07363860827653977,0.06890108046548278,0.06473606705441087,0.053984335299415785,0.02574051793193157,0.025668436401913693]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#  prediction    | 0.0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# only showing top 5 rows

# %%
correct_predictions2 = predictions_rf.filter("label == prediction").count()
print("correct_predictions is {}".format(correct_predictions2))
all_predictions2 = predictions_rf.count()
print("all_predictions is {}".format(all_predictions2))

print("Accuracy is {}".format(correct_predictions2 / all_predictions2))
# Out:
# correct_predictions is 1761
# all_predictions is 7228
# Accuracy is 0.24363586054233535

# %% [markdown]
# ## streaming
# foreach_batch_function

# %%
def foreach_batch_function(batch_df, batch_id):
    value_schema = StructType(fields=[StructField('uid', StringType()),
                                      StructField('visits', StringType())
                                      ])
    kafka_pre = batch_df.withColumn("temp", from_json("value", value_schema))
    visits_schema = ArrayType(StructType(fields=[StructField('url', StringType()),
                                                 StructField('timestamp', StringType())
                                                ]))
    kafka_pre2 = kafka_pre.select(F.col('temp.uid').alias('uid'), F.from_json('temp.visits', visits_schema).alias('visits'))
    kafka_data = kafka_pre2.withColumn('visited_pages', F.col('visits.url'))
    
    kafka_df3 = kafka_data.withColumn("new_column",expr('transform(visited_pages,x -> split(x,"://")[1])'))
    kafka_df4 = kafka_df3.withColumn("hosts",expr('transform(new_column,x -> split(x,"/")[0])')).select('uid','visited_pages','hosts')

    kafka_df5 = kafka_df4.withColumn("count", F.size("hosts")) \
            .withColumn("count_distinct", F.size(F.array_distinct("hosts")))
    kafka_df6 = kafka_df5.withColumn('fr_h', F.col('count')/F.col('count_distinct'))

    kafka_preprocessed_dataset = dataset_rfFit.transform(kafka_df6).select('uid','features')
    
    kafka_predictions = rfModel.transform(kafka_preprocessed_dataset)
    
    kafka_df_submit = kafka_predictions.withColumn('gender',when(F.col('prediction') == 0.0, 'M')\
                   .when(F.col('prediction') == 1.0, 'F') \
                   .when(F.col('prediction') == 2.0, 'M') \
                   .when(F.col('prediction') == 3.0, 'F') \
                   .when(F.col('prediction') == 4.0, 'F') \
                   .when(F.col('prediction') == 5.0, 'F') \
                   .when(F.col('prediction') == 6.0, 'M') \
                   .when(F.col('prediction') == 7.0, 'M') \
                   .when(F.col('prediction') == 8.0, 'F') \
                    .otherwise('M')) \
                .withColumn('age', when(F.col('prediction') == 0.0, '25-34')\
                   .when(F.col('prediction') == 1.0, '25-34') \
                   .when(F.col('prediction') == 2.0, '35-44') \
                   .when(F.col('prediction') == 3.0, '35-44') \
                   .when(F.col('prediction') == 4.0, '18-24') \
                   .when(F.col('prediction') == 5.0, '45-54') \
                   .when(F.col('prediction') == 6.0, '45-54') \
                   .when(F.col('prediction') == 7.0, '18-24') \
                   .when(F.col('prediction') == 8.0, '>=55') \
                    .otherwise('>=55')) \
                    .select('uid','gender','age')
    
    kafka_submit_js = kafka_df_submit.select(to_json(struct("uid","gender","age")).alias("value"))
    
    kafka_submit_js.write\
    .format('kafka')\
    .options(**write_kafka_params)\
    .mode('append')\
    .save()
    pass

# %%
def create_console_sink(df):
    return df.writeStream.foreachBatch(foreach_batch_function).option('checkpointLocation', 'streaming/chk/chk_kafka')

read_kafka_params = {
    "kafka.bootstrap.servers": 'spark-master-1.newprolab.com:6667',
    "subscribe": "input_zarina.kamytbaeva",
    "startingOffsets": "latest"
    }
kafka_sdf = spark.readStream.format("kafka").options(**read_kafka_params).option("failOnDataLoss", 'False').load()
kafka_sdf = kafka_sdf.select(col("value").cast("string"))

# %%
sink = create_console_sink(kafka_sdf)
sq = sink.start()

# %%
kafka_sdf.isStreaming
# Out:
# True

# %%
sq.isActive
# Out:
# True

# %%
# !hdfs dfs -ls streaming/chk/chk_kafka
# Out:
# Found 4 items
# drwxr-xr-x   - zarina.kamytbaeva zarina.kamytbaeva          0 2021-03-25 11:01 streaming/chk/chk_kafka/commits
# -rw-r--r--   3 zarina.kamytbaeva zarina.kamytbaeva         45 2021-03-24 17:52 streaming/chk/chk_kafka/metadata
# drwxr-xr-x   - zarina.kamytbaeva zarina.kamytbaeva          0 2021-03-25 11:01 streaming/chk/chk_kafka/offsets
# drwxr-xr-x   - zarina.kamytbaeva zarina.kamytbaeva          0 2021-03-24 17:52 streaming/chk/chk_kafka/sources

# %%
def kill_all():
    streams = SparkSession.builder.getOrCreate().streams.active
    for s in streams:
        desc = s.lastProgress["sources"][0]["description"]
        s.stop()
        print("Stopped {s}".format(s=desc))
#

# %%
kill_all()

# %%
spark.stop()
